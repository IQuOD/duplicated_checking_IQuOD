# %%
### run this command, and then input "./DC_OCEAN/Input_files/WOD18_sample_1995"
# %run ./DC_OCEAN/support/N00_read_data_metadata.py
# Out:
# Please enter the path to your netCDF files: ./DC_OCEAN/Input_files/WOD18_sample_1995
# F:\DC_OCEAN_test\DC_OCEAN-1.2\DC_OCEAN\Input_files\WOD18_sample_1995
# Processing file 1/1883: wod_004181522O.nc
# Processing file 2/1883: wod_004181523O.nc
# Processing file 3/1883: wod_004181524O.nc
# Processing file 4/1883: wod_004181525O.nc
# Processing file 5/1883: wod_004181526O.nc
# Processing file 6/1883: wod_004181527O.nc
# Processing file 7/1883: wod_007274385O.nc
# Processing file 8/1883: wod_007274386O.nc
# Processing file 9/1883: wod_007274387O.nc
# Processing file 10/1883: wod_007274388O.nc
# Processing file 11/1883: wod_007274389O.nc
# Processing file 12/1883: wod_007274390O.nc
# Processing file 13/1883: wod_007274391O.nc
# Processing file 14/1883: wod_007274392O.nc
# Processing file 15/1883: wod_007274393O.nc
# Processing file 16/1883: wod_007274394O.nc
# Processing file 17/1883: wod_007274395O.nc
# Processing file 18/1883: wod_007274396O.nc
# ...

# %%
### Step2: run this command, and then input "./DC_OCEAN/Input_files/DNA_summary.npz"
# %run ./DC_OCEAN/support/N01_possible_duplicates.py
# Out:
# Please enter the path to your DNA summary files (*.npz): ./DC_OCEAN/Input_files/DNA_summary.npz
# loading the DNA summary files....
# Running the Crude Screen check: the No.1 criteria check...
# Running the Crude Screen check: the No.2 criteria check...
# Running the Crude Screen check: the No.3 criteria check...
# Running the Crude Screen check: the No.4 criteria check...
# Running the Crude Screen check: the No.5 criteria check...
# Running the Crude Screen check: the No.6 criteria check...
# Running the Crude Screen check: the No.7 criteria check...
# Running the Crude Screen check: the No.8 criteria check...
# Running the Crude Screen check: the No.9 criteria check...
# Running the Crude Screen check: the No.10 criteria check...
# Running the Crude Screen check: the No.11 criteria check...
# Running the Crude Screen check: the No.12 criteria check...
# Running the Crude Screen check: the No.13 criteria check...
# Running the Crude Screen check: the No.14 criteria check...
# ...

# %%
### step3: run this command, and then first input "./DC_OCEAN/Input_files/sorted_unique_pairs_generic.txt", then secondly input "./DC_OCEAN/Input_files/WOD18_sample_1995"
# %run ./DC_OCEAN/M02_MAIN_check_nc_duplicate_list.py

##### The return files "Unduplicatelist_sorted_unique_pairs_generic.txt" and "DuplicateList_sorted_unique_pairs_generic.txt" are the final result
# Out:
# Please input the path with filename (*.txt) of the potential duplicated list output from N01_possible_duplicates.py (e.g., sorted_unique_pairs_generic.txt):./DC_OCEAN/Input_files/sorted_unique_pairs_generic.txt
# Please input the corresponding netCDF files path:./DC_OCEAN/Input_files/WOD18_sample_1995
#
#
# Spatial-temporal checks--Simultaneously but at different location: 0
# Spatial-temporal checks--Simultaneously and co-located: 0
# Correlation check: 0
# Truncation check: 0
# Layer by layer check - wrong location: 1
# Layer by layer check - wrong date: 1
# Layer by layer check - wrong time: 0
# Layer by layer check - wrong country: 0
# Layer by layer check - wrong instrument: 0
# Exact duplicates check: 0
# Interpolation (missing data) check: 0
# CTD double data check: 0
# wod_007274799O.nc wod_007275047O.nc
# wod_007274799O.nc v.s. wod_007275047O.nc: Possible Duplicate
#
#
# Spatial-temporal checks--Simultaneously but at different location: 0
# ...
